# %%
import pandas as pd
import requests

# %%
last_movie_ids = [movie['id'] for movie in response['data']['movies']]
# last_movie_ids = last_movie_ids[:7]
last_movie_ids
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# The following code helps to determine whether new data is inserted in api database or not, if so then we have to pull new movies data and put that in database and update tracking parameters.

# %%
# code to capture data change (ie gather new data from api)
last_run_length = 7
last_page = 819 # let say last time movies count was, 7 now it is 50, so we need to pick up new movies....

response =  requests.get(f'https://yts.torrentbay.to/api/v2/list_movies.json?page={last_page}&limit=50').json()

# check if last list of moives is same as now:

if len(response['data']['movies']) == last_run_length:
  print('no new movies found.')
elif len(response['data']['movies']) > last_run_length:
  cnt = 0
  for movie in response['data']['movies']:
    if movie['id'] not in last_movie_ids:
      cnt += 1

  print(f'found {cnt} new movies')
# Out:
# no new movies found.

# %%
response =  requests.get('https://yts.torrentbay.to/api/v2/list_movies.json?page=819&limit=50')

# %%
response.json()
# Out:
# {'status': 'ok',
#  'status_message': 'Query was successful',
#  'data': {'movie_count': 40931,
#   'limit': 50,
#   'page_number': 819,
#   'movies': [{'id': 36,
#     'url': 'https://yts.torrentbay.to/movies/28-weeks-later-2007',
#     'imdb_code': 'tt0463854',
#     'title': '28 Weeks Later',
#     'title_english': '28 Weeks Later',
#     'title_long': '28 Weeks Later (2007)',
#     'slug': '28-weeks-later-2007',
#     'year': 2007,
#     'rating': 6.9,
#     'runtime': 100,
#     'genres': ['Action', 'Adventure', 'Drama', 'Horror', 'Sci-Fi'],
#     'summary': '',
#     'description_full': '',
#     'synopsis': '',
#     'yt_trailer_code': 'kbuCnTZvTvQ',
#     'language': 'en',
#     'mpa_rating': 'R',
#     'background_image': 'https://yts.torrentbay.to/assets/images/movies/28_Weeks_Later_2007/background.jpg',
#     'background_image_original': 'https://yts.torrentbay.to/assets/images/movies/28_Weeks_Later_2007/background.jpg',
# ...
